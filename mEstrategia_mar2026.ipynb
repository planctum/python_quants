# %% [markdown]
# <a href="https://colab.research.google.com/github/planctum/python_quants/blob/main/mEstrategia_mar2026.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Download IBXL, IBXX and IBOV into dataframes

# %%
import pandas as pd

# %%
# download the IBXL (ibrx-50)
df_dados = pd.read_csv('/content/IBXL-50_23-03-26.csv',
                           encoding='utf-8',
                           sep='\t', # Use tab as separator
                           #decimal=',', # Uncommented to correctly parse numbers with comma as decimal
                           header=0, # Use the first line as header (0-indexed)
                           engine='python' # Using 'python' engine can sometimes help with complex parsing scenarios
                          )

print(df_dados)
lista_codigos = df_dados['Codigo'].tolist()
print(lista_codigos)
# Out:
#     Codigo          Acao Part. (%)
# 0    ABEV3     AMBEV S/A      2,49
# 1    ASAI3         ASSAI     0,397
# 2    AXIA3  AXIA ENERGIA     4,425
# 3    AXIA7  AXIA ENERGIA     1,114
# 4    B3SA3            B3     3,387
# 5    BBSE3  BBSEGURIDADE     0,846
# 6    BBDC3      BRADESCO     0,934
# 7    BBDC4      BRADESCO     3,769
# 8    BBAS3        BRASIL     2,663
# 9    BRAV3         BRAVA     0,315
# 10  BPAC11    BTGP BANCO     2,983
# 11   CMIG4         CEMIG     0,938
# 12   COGN3      COGNA ON     0,217
# 13   CPLE3         COPEL     1,773
# 14   CSAN3         COSAN      0,37
# 15   CYRE3  CYRELA REALT     0,258
# 16   CYRE4  CYRELA REALT     0,045
# 17   EMBJ3       EMBRAER     2,105
# 18  ENGI11      ENERGISA     0,704
# 19   ENEV3         ENEVA     1,925
# 20   EQTL3    EQUATORIAL     2,014
# 21   GGBR4        GERDAU     0,888
# 22   HAPV3       HAPVIDA     0,104
# 23   ITSA4        ITAUSA     3,149
# 24   ITUB4  ITAUUNIBANCO     8,951
# 25  KLBN11    KLABIN S/A     0,587
# ...

# %%
# download the IBXX (ibrx-100)
df_dados = pd.read_csv('/content/IBXX-100_23-03-26.csv',
                           encoding='utf-8',
                           sep='\t', # Use tab as separator
                           #decimal=',',
                           header=0, # Use the first line as header (0-indexed)
                           engine='python' # Using 'python' engine can sometimes help with complex parsing scenarios
                          )

print(df_dados)
lista_codigos = df_dados['Codigo'].tolist()
print(lista_codigos)
# Out:
#     Codigo         Acao Part. (%)
# 0    ALOS3        ALLOS     0,493
# 1    ABEV3    AMBEV S/A     2,272
# 2    ANIM3        ANIMA     0,036
# 3    ASAI3        ASSAI     0,362
# 4    AURE3        AUREN     0,132
# ..     ...          ...       ...
# 96   VAMO3        VAMOS     0,053
# 97   VBBR3        VIBRA     1,275
# 98   VIVA3  VIVARA S.A.     0,116
# 99   WEGE3          WEG     2,505
# 100  YDUQ3   YDUQS PART     0,098
#
# [101 rows x 3 columns]
# ...

# %%
# download the IBOV
df_dados = pd.read_csv('/content/IBOV_23-03-26.csv',
                           encoding='utf-8',
                           sep='\t', # Use tab as separator
                           #decimal=',',
                           header=0, # Use the first line as header (0-indexed)
                           engine='python' # Using 'python' engine can sometimes help with complex parsing scenarios
                          )

print(df_dados)
lista_codigos = df_dados['Codigo'].tolist()
print(lista_codigos)
# Out:
#    Codigo          Acao Part. (%)
# 0   ALOS3         ALLOS     0,525
# 1   ABEV3     AMBEV S/A     2,417
# 2   ASAI3         ASSAI     0,385
# 3   AURE3         AUREN     0,141
# 4   AXIA3  AXIA ENERGIA     4,232
# ..    ...           ...       ...
# 78  VAMO3         VAMOS     0,056
# 79  VBBR3         VIBRA     1,355
# 80  VIVA3   VIVARA S.A.     0,123
# 81  WEGE3           WEG     2,665
# 82  YDUQ3    YDUQS PART     0,104
#
# [83 rows x 3 columns]
# ...
